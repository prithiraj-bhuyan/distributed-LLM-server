# %% [markdown]
# 1) Recursion Example

# %%
def recursive_sum(n):
    """
    Goal: Calculate the sum of all numbers from n down to 0.
    """
    # TODO 1: Write the Base Case.
    
    
    # TODO 2: Write the Recursive Step.
    raise NotImplementedError

# Test the function
print(f"Sum of 3: {recursive_sum(3)}")  # Expected: 6
print(f"Sum of 5: {recursive_sum(5)}")  # Expected: 15

# %% [markdown]
# 2. Decision Trees Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def predict_dt(datum, tree):
    # TODO 1: Write the Base Case.
    
    
    feature_name = tree['Feature']
    val = datum[feature_name]
    
    # TODO 2: Write the Recursive Step.
    raise NotImplementedError

# %%
# -------------------------------------------------
# TREE DEFINITION (Price vs. Shelf Life) | DO NOT MODIFY
# -------------------------------------------------
my_tree = {
    'Feature': 'price',
    'Condition': lambda x: x > 20, # Is price > $20?
    
    # LEFT BRANCH (Price > 20)
    'IfTrue': {
        'Feature': 'shelf_life',
        'Condition': lambda x: x > 7, # Is shelf life > 7 days?
        'IfTrue':  {'Value': 'PREMIUM'},# Leaf
        'IfFalse': {'Value': 'LUXURY'}  # Leaf
    },
    
    # RIGHT BRANCH (Price <= 20)
    'IfFalse': {
        'Feature': 'shelf_life',
        'Condition': lambda x: x > 7, # Is shelf life > 7 days?
        'IfTrue':  {'Value': 'STANDARD'},  # Leaf
        'IfFalse': {'Value': 'CLEARANCE'}  # Leaf
    }
}

# -------------------------------------------------
# TEST CASES
# -------------------------------------------------
# Product 1: Expensive, long-lasting wine
product_1 = {'price': 50, 'shelf_life': 365}
print(f"Product 1: {predict_dt(product_1, my_tree)}") 

# Product 2: Cheap, short-life sandwich
product_2 = {'price': 5, 'shelf_life': 2}
print(f"Product 2: {predict_dt(product_2, my_tree)}")

# Product 3: Expensive, short-life truffle
product_3 = {'price': 100, 'shelf_life': 3}
print(f"Product 3: {predict_dt(product_3, my_tree)}")

# %% [markdown]
# 3. Linear Regression Example

# %%
import numpy as np

def calculate_predictions():
    """
    Goal: Compute Y = XW
    """
    X = np.array([
        [2, 1], 
        [5, 10]
    ])
    
    W = np.array([
        [3],
        [2]
    ])
    
    # TODO: Calculate Y using matrix multiplication.
    raise NotImplementedError

    return Y

predictions = calculate_predictions()
print("Predicted Scores (Y):")
print(predictions)
